# %% [markdown]
# <a href="https://colab.research.google.com/github/bishal454/AI_PROJECT/blob/main/real_estate_price_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
matplotlib.rcParams["figure.figsize"] = (20,10)
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv("Lucknow_House_Data.csv")
df1.head()
# Out:
#               area_type   availability                   location       size  \
# 0  Super built-up  Area         19-Dec                Gomti Nagar      2 BHK
# 1            Plot  Area  Ready To Move     Sultanpur Lucknow Road  4 Bedroom
# 2        Built-up  Area  Ready To Move                  Ansal API      3 BHK
# 3  Super built-up  Area  Ready To Move  amar shaheed path lucknow      3 BHK
# 4  Super built-up  Area  Ready To Move                  Arjunganj      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df1.shape
# Out:
# (13320, 9)

# %%
df1.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df1['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Plot  Area', 'Built-up  Area',
#        'Carpet  Area'], dtype=object)

# %%
df1['area_type'].value_counts()
# Out:
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64

# %%
df2 = df1.drop(['area_type','society','balcony','availability'],axis='columns')
df2.shape
# Out:
# (13320, 5)

# %% [markdown]
# # **Data Cleaning : Handling NA Values**

# %%
df2.isnull().sum()
# Out:
# location       0
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df2.shape
# Out:
# (13320, 5)

# %%
df3 = df2.dropna()
df3.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
df3.shape
# Out:
# (13247, 5)

# %% [markdown]
# # **Feature Engineering :**
# # Add new feature(integer) for bhk (Bedrooms Hall Kitchen)

# %%
df3['bhk'] = df3['size'].apply(lambda x: int(x.split(' ')[0]))
df3.bhk.unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18])

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
is_float(4.0)
# Out:
# True

# %%
df3[~df3['total_sqft'].apply(is_float)].head(10)
# Out:
#                            location       size      total_sqft  bath    price  \
# 30   sultanpur road near shaheed pa      4 BHK     2100 - 2850   4.0  186.000
# 122                         Lalbagh      4 BHK     3067 - 8156   4.0  477.000
# 137          Sultanpur Lucknow Road      2 BHK     1042 - 1105   2.0   54.005
# 165           Gomti Nagar Extension      2 BHK     1145 - 1340   2.0   43.490
# 188                      Gosainganj      2 BHK     1015 - 1540   2.0   56.800
# 410                      Cantonment      1 BHK  34.46Sq. Meter   1.0   18.500
# 549                      Cantonment      2 BHK     1195 - 1440   2.0   63.770
# 648                      Cantonment  9 Bedroom       4125Perch   9.0  265.000
# 661                         ahmamau      2 BHK     1120 - 1145   2.0   48.130
# 672                     Mohaan Road  4 Bedroom     3090 - 5002   4.0  445.000
#
#      bhk
# 30     4
# 122    4
# 137    2
# 165    2
# 188    2
# 410    1
# 549    2
# 648    9
# 661    2
# 672    4

# %% [markdown]
# # Above shows that total_sqft can be a range (e.g. 2100-2850). For such cases we can just take average of min and max value in the range. There are other cases such as 34.46Sq. Meter and 4125Perch which one can convert to square ft using unit conversion or just drop such cases and try to keep things simple.

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
convert_sqft_to_num('2560')
# Out:
# 2560.0

# %%
convert_sqft_to_num('2100 - 2850')
# Out:
# 2475.0

# %%
df4 = df3.copy()
df4.total_sqft = df4.total_sqft.apply(convert_sqft_to_num)
df4 = df4[df4.total_sqft.notnull()]
df4.head(10)
# Out:
#                                    location       size  total_sqft  bath  \
# 0                               Gomti Nagar      2 BHK      1056.0   2.0
# 1                    Sultanpur Lucknow Road  4 Bedroom      2600.0   5.0
# 2                                 Ansal API      3 BHK      1440.0   2.0
# 3                 amar shaheed path lucknow      3 BHK      1521.0   3.0
# 4                                 Arjunganj      2 BHK      1200.0   2.0
# 5                                 Arjunganj      2 BHK      1170.0   2.0
# 6  Purvanchal Expressway Under Construction      4 BHK      2732.0   4.0
# 7                                Hazratganj      4 BHK      3300.0   4.0
# 8                               Gomti Nagar      3 BHK      1310.0   3.0
# 9                                 Arjunganj  6 Bedroom      1020.0   6.0
#
#     price  bhk
# 0   39.07    2
# 1  120.00    4
# 2   62.00    3
# 3   95.00    3
# 4   51.00    2
# 5   38.00    2
# 6  204.00    4
# 7  600.00    4
# 8   63.25    3
# 9  370.00    6

# %%
df4.loc[30]
# Out:
# location      sultanpur road near shaheed pa
# size                                   4 BHK
# total_sqft                            2475.0
# bath                                     4.0
# price                                  186.0
# bhk                                        4
# Name: 30, dtype: object

# %%
# @title area_type vs price

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df1['area_type'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df1, x='price', y='area_type', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# @title area_type vs balcony

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df1['area_type'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df1, x='balcony', y='area_type', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# @title area_type vs bath

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(df1['area_type'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(df1, x='bath', y='area_type', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)

# %%
# @title price

from matplotlib import pyplot as plt
df1['price'].plot(kind='line', figsize=(8, 4), title='price')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title balcony

from matplotlib import pyplot as plt
df1['balcony'].plot(kind='line', figsize=(8, 4), title='balcony')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title bath

from matplotlib import pyplot as plt
df1['bath'].plot(kind='line', figsize=(8, 4), title='bath')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title balcony vs price

from matplotlib import pyplot as plt
df1.plot(kind='scatter', x='balcony', y='price', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title bath vs balcony

from matplotlib import pyplot as plt
df1.plot(kind='scatter', x='bath', y='balcony', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title area_type

from matplotlib import pyplot as plt
import seaborn as sns
df1.groupby('area_type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title price

from matplotlib import pyplot as plt
df1['price'].plot(kind='hist', bins=20, title='price')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title balcony

from matplotlib import pyplot as plt
df1['balcony'].plot(kind='hist', bins=20, title='balcony')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title bath

from matplotlib import pyplot as plt
df1['bath'].plot(kind='hist', bins=20, title='bath')
plt.gca().spines[['top', 'right',]].set_visible(False)
